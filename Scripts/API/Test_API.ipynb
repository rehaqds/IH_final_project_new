# %%
# Test the API

# %%
import requests
import json

# %%
url = "http://localhost:8080/help"

response = requests.get(url)
result = response.json()
print(result['message'])
# print(json.dumps(result, indent=4, sort_keys=False))
# Out:
#  Instructions to access the data:
# End Point 1:   http://localhost:8080/persons/123
# This API gives all the information available for a given person based on his ID.
#
# End Point 2:   http://localhost:8080/persons?page=2&page_size=5
# This API allows the user to request all the information in the main table from BRFSS. As there are 275k persons in the database, the user can add the optional parameters page and page_size to display the data for the page number chosen on the basis of the page_size given.
# The API returns the data requested and the url of the next page and the url of the last possible page.
#
# End Point 3:   http://localhost:8080/states/pollution/texas
# This API gives the air pollution level for the chosen state.
#
# End Point 4:   http://localhost:8080/states/population/california
# This API gives the population for the chosen state.

# %%
url = "http://localhost:8080/persons?page=2&page_size=10"

response = requests.get(url)
result = response.json()
print(json.dumps(result, indent=4, sort_keys=False))
# Out:
# {
#     "last_page": "/persons?page=27276&page_size=10",
#     "next_page": "/persons?page=3&page_size=10",
#     "persons": [
#         {
#             "age": 57.0,
#             "alcohol": "0.0",
#             "arthritis": "no",
#             "asthma": "yes",
#             "blood_pressure": "no",
#             "bmi": "obese",
#             "cancer": 0,
#             "cholesterol": "no",
#             "cvd": 0,
#             "depression": "no",
#             "diabete": "yes",
#             "education": "high-school",
#             "fruits": "2.0",
#             "general_health": 3.0,
#             "height": "1.63",
#             "income": "75-100k",
#             "is_urban": "yes",
#             "med_cost_issue": "no",
#             "person_id": 21,
#             "physical_activity": "no",
#             "race": "white",
#             "sex": "F",
#             "smoked_100_cig": "yes",
#             "state_id": 1,
#             "stroke": "no",
#             "vegetables": "1.9",
# ...

# %%
url = "http://localhost:8080/persons/123"

response = requests.get(url)
# print(response)

result = response.json()
print(json.dumps(result, indent=4, sort_keys=False))
# Out:
# {
#     "age": 62.0,
#     "alcohol": 0.0,
#     "arthritis": "no",
#     "asthma": "no",
#     "blood_pressure": "no",
#     "bmi": "overweight",
#     "cancer": 0,
#     "cholesterol": "no",
#     "cvd": 0,
#     "depression": "no",
#     "diabete": "no",
#     "education": "high-school",
#     "fruits": 0.17,
#     "general_health": 1.0,
#     "height": 1.8554000000000002,
#     "income": "10-15k",
#     "is_urban": "yes",
#     "med_cost_issue": "no",
#     "person_id": 123,
#     "physical_activity": "no",
#     "race": "white",
#     "sex": "M",
#     "smoked_100_cig": "no",
#     "state_id": 1,
#     "stroke": "no",
#     "vegetables": 1.3,
#     "veteran": "no",
#     "weight": 87.0912
# }

# %%
url = "http://localhost:8080/states/pollution/texas"

response = requests.get(url)
# print(response)
result = response.json()
print(json.dumps(result, indent=4, sort_keys=False))
# Out:
# {
#     "Air Pollution": 7.300000190734863
# }

# %%
url = "http://localhost:8080/states/population/california"

response = requests.get(url)
# print(response)
result = response.json()
print(json.dumps(result, indent=4, sort_keys=False))
# Out:
# {
#     "Population": 39455353
# }
